# %%
import pandas as pd

# %%
regional_data = pd.read_csv("/content/company_data.csv")

regional_df = pd.DataFrame(regional_data)

regional_df.head()
# Out:
#    Market Department_Name  Days_for_shipping_real  \
# 0  Africa         Apparel                       0
# 1  Africa         Apparel                       0
# 2  Africa         Apparel                       0
# 3  Africa         Apparel                       0
# 4  Africa         Apparel                       0
#
#    Days_for_shipment_scheduled Order_Status  Order_Item_Product_Price  \
# 0                            0       CLOSED                 39.990002
# 1                            0       CLOSED                 59.990002
# 2                            0     COMPLETE                129.990005
# 3                            0     COMPLETE                 39.990002
# 4                            0      PENDING                129.990005
#
#    Order_Item_Profit_Ratio Customer_Segment
# 0                     0.12         Consumer
# 1                    -0.25      Home Office
# 2                     0.43         Consumer
# 3                    -0.67         Consumer
# ...

# %%
regional_df.columns
# Out:
# Index(['Market', 'Department_Name', 'Days_for_shipping_real',
#        'Days_for_shipment_scheduled', 'Order_Status',
#        'Order_Item_Product_Price', 'Order_Item_Profit_Ratio',
#        'Customer_Segment'],
#       dtype='object')

# %%
market_df = regional_df.set_index('Market')

# %%
market_df.value_counts('Market')
# Out:
# Market
# Europe          90682
# LATAM           53265
# Pacific Asia    33358
# Africa          24697
# USCA            23536
# Name: count, dtype: int64

# %%
department_type_df = market_df.Department_Name.value_counts()

department_type_df
# Out:
# Department_Name
# Fan Shop              65443
# Apparel               65272
# Golf                  44975
# Footwear              24933
# Outdoors              17556
# Fitness                4534
# Technology             1169
# Discs Shop              985
# Book Shop               315
# Pet Shop                206
# Health and Beauty       150
# Name: count, dtype: int64
